# %%
import sys
import os
sys.path.append('../')

from src import generate_trajectory_Langevin_2D_from_symbolic as gen_traj

from src import generate_potential_2d_Zshape as gen_zshape
from src import generate_potential_2d_spiral as gen_spiral
import numpy as np
import json
import sympy as spy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def concatenate(data):
    cdata = data[0]
    for i in range(1, len(data)):
        cdata = np.concatenate((cdata, data[i]), axis=1)
    return cdata

# %%
fd = "/home/ucapzwe/generate_data/matlab2py/CLIBuild/script/zshape_traj_Mconfig_2022-05-22-4/zshape_traj_Mconfig_2022-05-22.json"
father_path = os.path.abspath(os.path.dirname(fd) + os.path.sep + ".")
father_path
# Out:
# '/home/ucapzwe/generate_data/matlab2py/CLIBuild/script/zshape_traj_Mconfig_2022-05-22-4'

# %%
result = np.load("/home/ucapzwe/generate_data/matlab2py/CLIBuild/script/zshape_traj_Mconfig_2022-05-22/result.npy")

# %%
for traj in result:
    plt.scatter(traj[0], traj[1])

# %%
result_con = concatenate(result)
sns.jointplot(x=result_con[0],y=result_con[1])

# %%
result2 = np.load('/home/ucapzwe/generate_data/matlab2py/CLIBuild/script/zshape_traj_Mconfig_2022-05-23/result.npy')

# %%
for traj in result2:
    plt.scatter(traj[0], traj[1])

# %%
result2_con = concatenate(result2)
sns.jointplot(x=result2_con[0],y=result2_con[1])

# %%
sns.jointplot(x=result2_con[0],y=result2_con[1],kind='hex')

# %%
result_s = np.load('/home/ucapzwe/generate_data/matlab2py/CLIBuild/script/spiral_traj_Mconfig_2022-05-22/result.npy')

# %%
for traj in result_s:
    plt.scatter(traj[0], traj[1])

# %%
results_con = concatenate(result_s)
sns.jointplot(x=results_con[0],y=results_con[1])

# %%
result_s1 = np.load('/home/ucapzwe/generate_data/matlab2py/CLIBuild/script/spiral_traj_Mconfig_2022-05-22-1/result.npy')

# %%
for traj in result_s1:
    plt.scatter(traj[0], traj[1])

# %%
result_s1_con = concatenate(result_s1)
sns.jointplot(x=result_s1_con[0],y=result_s1_con[1])

# %%
result_s2 = np.load('/home/ucapzwe/generate_data/matlab2py/CLIBuild/script/spiral_traj_Mconfig_2022-05-22-2/result.npy')

# %%
for traj in result_s2:
    plt.scatter(traj[0], traj[1])

# %%
result_s2_con = concatenate(result_s2)
sns.jointplot(x=result_s2_con[0],y=result_s2_con[1])

# %%
sns.jointplot(x=result_s2_con[0],y=result_s2_con[1], kind='hex')
